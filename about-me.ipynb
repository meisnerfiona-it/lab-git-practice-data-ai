# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Fiona Meisner"
reason = "I am interested in AI, Data Analytics, and Data Science because I find working with data and seeing what I can create, visualize, and work with within the data fascinating"
fun_fact = "One fun fact about me is that I love to be outdoors and have run a few half marathons."

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Fiona Meisner. I’m excited to learn because I am interested in AI, Data Analytics, and Data Science because I find working with data and seeing what I can create, visualize, and work with within the data fascinating. A fun fact about me is: One fun fact about me is that I love to be outdoors and have run a few half marathons..
